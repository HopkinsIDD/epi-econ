# %%
import pandas as pd
import numpy as np
from Model import Model
from collections import OrderedDict
from collections import namedtuple
from itertools import product

# %%
initial_space = [
    {'amount': 990, 'infection_status': 's', 'risk_group': 'g0-00'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g0-01'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g0-10'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g0-11'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g1-00'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g1-01'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g1-10'},
    {'amount': 0, 'infection_status': 's', 'risk_group': 'g1-11'},
    {'amount': 10, 'infection_status': 'i', 'risk_group': 'g0-00'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g0-01'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g0-10'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g0-11'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g1-00'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g1-10'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g1-01'},
    {'amount': 0, 'infection_status': 'i', 'risk_group': 'g1-11'}

]

# %%
params = OrderedDict(
    initial_condition = [initial_space], # Initial conditions
    n_epi = [10], # Number of epi updates between two decision updates
    beta = [0.6], # Infection rate
    r_base = [0.25], # basis contact rate
    r1 = [0.25], # Additional contact on diagonal entries
    r2 = [1], # Additional contacts between two work risk groups
    r3 = [0.5], # Additional contacts between low-SES risk groups
    alpha = [0.0], # rate from recovered to susceptible
    gamma = [0.1], # recovery rate
    theta_x = [-1], # penalty for being sick
    theta_k = [0.5], # Extra sensitivity of vulnerable population
    theta_h = [0], # Sensitivity to hassle costs
    B = [-10], # Payoff for making risky decision
    pc = [0.5], # Additional costs of risky behavior if infected
    mu = [0], # mean of log hassle cost
    sigma = [0.15], # std of log hassle cost
    threshold = [1e-5], # tolerance of solving Bellman function
    v = [0.57721], # Euler’s constant
    k = [0.9], # Discount factor
    c_l = [13], # Baseline level of consumption for low-SES
    c_h = [29], # Baseline level of consumption for high-SES
    w_l = [51], # Wage for low-SES individuals
    w_h = [115] # Wage for high-SES individuals
)

# %%
test = Model(initial_condition=initial_space,
                     n_epi=2,
                     beta=0.2,
                     r_base=0.25,
                     r1=0.25,
                     r2=0.25,
                     r3=0.25,
                     alpha=0,
                     gamma=0.1,
                     theta_x=-1,
                     theta_k=0.5,
                     theta_h=0,
                     B=-1,
                     pc=0.5,
                     mu=0,
                     sigma=0.15,
                     threshold=1e-5,
                     v=0.57721,
                     k=0.9,
                     c_l=13,
                     c_h=29,
                     w_l=51,
                     w_h=115)

# %%
test.__dict__
# Out:
# {'iteration': None,
#  'total_agent': [Agent with index = 0, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 1, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 2, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 3, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 4, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 5, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 6, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 7, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 8, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 9, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 10, time = 0, risk group = g0-00, infection status = s,
#   Agent with index = 11, time = 0, risk group = g0-00, infection status = s,
# ...

# %%
test.contact_matrix
# Out:
#        g0-00  g0-01  g0-10  g0-11  g1-00  g1-01  g1-10  g1-11
# g0-00   0.50   0.25   0.25   0.25   0.25   0.25   0.25   0.25
# g0-01   0.25   0.50   0.25   0.25   0.25   0.25   0.25   0.25
# g0-10   0.25   0.25   0.50   0.25   0.25   0.25   0.25   0.25
# g0-11   0.25   0.25   0.25   0.50   0.25   0.25   0.25   0.25
# g1-00   0.25   0.25   0.25   0.25   0.75   0.50   0.50   0.50
# g1-01   0.25   0.25   0.25   0.25   0.50   1.00   0.50   0.75
# g1-10   0.25   0.25   0.25   0.25   0.50   0.50   0.75   0.50
# g1-11   0.25   0.25   0.25   0.25   0.50   0.75   0.50   1.00

# %%
dir(Model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bellman_func',
#  'run',
#  'run_basic_SIR',
#  'transition_matrix',
#  'utility_func']

# %%
df = test.run(10)
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 10.18it/s]

# %%
df
# Out:
#          m   t  decision       state_VUL state_SES infection_status  \
# 0        0   0  not-work  not-vulnerable  high-SES                s
# 1        1   0  not-work  not-vulnerable  high-SES                s
# 2        2   0  not-work  not-vulnerable  high-SES                s
# 3        3   0  not-work  not-vulnerable  high-SES                s
# 4        4   0  not-work  not-vulnerable  high-SES                s
# ...    ...  ..       ...             ...       ...              ...
# 10995  995  10      work  not-vulnerable  high-SES                i
# 10996  996  10      work  not-vulnerable  high-SES                i
# 10997  997  10  not-work  not-vulnerable  high-SES                r
# 10998  998  10      work  not-vulnerable  high-SES                i
# 10999  999  10      work  not-vulnerable  high-SES                r
#
#       risk_group hassle_cost_group
# 0          g0-00               low
# 1          g0-00              high
# 2          g0-00              high
# ...
